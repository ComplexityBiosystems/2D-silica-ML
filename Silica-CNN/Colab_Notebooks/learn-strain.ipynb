# %% [markdown]
# ### Load standard libraries

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from pathlib import Path
import matplotlib.pyplot as plt
# %matplotlib inline

import glob
from collections import Counter
import seaborn as sns

import matplotlib as mpl
mpl.rcParams['axes.titlesize'] = 18
mpl.rcParams['axes.labelsize'] = 14
mpl.rcParams['legend.fontsize'] = 14
mpl.rcParams['xtick.labelsize'] = 14
mpl.rcParams['ytick.labelsize'] = 14

from scipy.stats import linregress
from skimage.transform import rescale

# %% [markdown]
# ### Load data
# The data is Google Drive's fontclosgpu@gmail.com account. We **mount** the drive and untar the data in the ephemeral Google Colab instance we have been given.

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %% [markdown]
# Set basedir where we are going to operate

# %%
BASEDIR = Path("/content/drive/MyDrive/silicanets-data/")

# %% [markdown]
# We first read just the metadata, which has paths to images and targets. This is enough to do data resmapling to turn the target uniform and train validation test splitting.

# %% [markdown]
# ### Set global parameters
# Here we choose the number of runs, number of samples, max training epochs and dropout level.

# %%
# choose training dataset
training_data_disorder_variance = "variable"

if isinstance(training_data_disorder_variance, float):
  varcode = str(int(10 * training_data_disorder_variance))
  compressed_data = f"ml_dataset_var0{varcode}.tar.gz"

elif training_data_disorder_variance == "variable":
  compressed_data = "ml_dataset_variable_var.tar.gz"

else:
  raise NotImplementedError


try:
  df = pd.read_csv("ml_dataset/metadata.csv")
except:
  ! tar xzf {BASEDIR / "data" / compressed_data}
  df = pd.read_csv("ml_dataset/metadata.csv")

# OPTION MODEL SUBSET STRAIN
# REMOVE WHEN DONE
# take only 2/3 of samples with lowest rupture strain
#df = df.loc[df.break_strain <= df.break_strain.quantile(2/3)].copy()

try:
  del history_df
except:
  pass

num_samples = "all" # a number or "all"
num_runs = "all" # a number or "all"
max_epochs = 200
dropout = 0
scale = 0.5

# for the lazy types
if num_samples == "all":
  num_samples = len(df)
if num_runs == "all":
  num_runs = len(df.run.unique())

assert num_runs <= len(df.run.unique())

# %%
if training_data_disorder_variance == "variable":
  disorder_df = pd.read_csv(BASEDIR / "data" / "variable_disorder_missing_metadata_column.txt", header=None, sep=" ", names=["run", "disorder"])
  disorder_df["run"] = disorder_df.run.apply(lambda x: f"run_{x:05d}")
  df["disorder_var"] = df.run.map(dict(disorder_df.values))

# %% [markdown]
# ### Subsample data
# Because the distribution of failure strain is approx gaussian, the model tends to predict average failure strain (similar to class imbalance problem). Given that we have access to unlimited amounts of data (in the form of data augmentation but if needed we could also run more simulations), what we do is to select a different number of images from each run, in a way that the final density of target is closer to uniform.

# %% [markdown]
# First select a subset of runs, this is just to study the effect of number of runs on final accuracy

# %%
assert num_runs <= len(df.run.unique())
valid_runs = np.random.choice(df.run.unique(), size=num_runs, replace=False)
_idx = df.run.apply(lambda x: x in valid_runs)
df = df.loc[_idx].copy()

# %% [markdown]
# Then do the proper data-augmentation level subsampling to render the target uniform.

# %%
df_subsampled = df.sample(num_samples)

# %% [markdown]
# ### Create output dir
# Create a new, unique directory to store all outputs of this round.

# %%
import datetime
model_name = "resnet-strain-variable-" + datetime.datetime.now().isoformat().split(".")[0]
! mkdir -p {BASEDIR / "output" / model_name / "checkpoints"}
! mkdir -p {BASEDIR / "output" / model_name / "dataframes"}
! mkdir -p {BASEDIR / "output" / model_name / "figures"}

# %% [markdown]
# Save dfs for reproducibility

# %%
pd.to_pickle(df, BASEDIR / "output" / model_name / "dataframes" / "df.p")
pd.to_pickle(df_subsampled, BASEDIR / "output" / model_name / "dataframes" / "df_subsampled.p")

# %%
num_runs = len(df_subsampled.run.unique())
num_images = len(df_subsampled)

# %%
info = {
    "model_name": model_name,
    "num_runs": num_runs,
    "num_images": num_images,
    "max_epochs": max_epochs,
    "dropout": dropout,
    "scale": scale,
    "disorder_variance": training_data_disorder_variance,
    "loss": "mse"
}

# %%
pd.Series(info).to_csv(BASEDIR / "output" / model_name / "model_info.csv")

# %%
info
# Out:
# {'disorder_variance': 'variable',
#  'dropout': 0,
#  'loss': 'mse',
#  'max_epochs': 200,
#  'model_name': 'resnet-strain-variable-2022-02-22T18:24:14',
#  'num_images': 38912,
#  'num_runs': 608,
#  'scale': 0.5}

# %% [markdown]
# ### Split data
# We need to split the data into the standard train, validation, test sets, but respecting the original runs (otherwise we have copies of same run in different sets which is not ok)

# %%
def data_splitter(df, test_split=0.2):
  """Split the metadata dataframe into train and test sets
  keeping runs together, that is, not allowing different images
  of the same run to be in different sets.
  """
  runs_all = df["run"].unique()
  _run_splitter = int((1 - test_split) * len(runs_all))
  np.random.shuffle(runs_all)
  runs_train = runs_all[:_run_splitter]
  runs_test = runs_all[_run_splitter:]
  _idx_train = df.run.apply(lambda x: x in runs_train)
  _idx_test = df.run.apply(lambda x: x in runs_test)
  df_train = df.loc[_idx_train]
  df_test = df.loc[_idx_test]

  return df_train, df_test

# %%
df_train, df_test = data_splitter(df_subsampled, test_split = 0.2)
df_train, df_validation = data_splitter(df_train, test_split=0.1)

# %%
print(f"Saving metadata of train, test, validation for reproducibility:")
print(f"Train set: {len(df_train.run.unique())} runs ({len(df_train)} images)")
print(f"Validation set: {len(df_validation.run.unique())} runs ({len(df_validation)} images)")
print(f"Test set: {len(df_test.run.unique())} runs ({len(df_test)} images)")

df_train.to_pickle(BASEDIR / "output" / model_name / "dataframes" / "df_train.p")
df_validation.to_pickle(BASEDIR / "output" / model_name / "dataframes" / "df_validation.p")
df_test.to_pickle(BASEDIR / "output" / model_name / "dataframes" / "df_test.p")
# Out:
# Saving metadata of train, test, validation for reproducibility:
# Train set: 437 runs (27968 images)
# Validation set: 49 runs (3136 images)
# Test set: 122 runs (7808 images)

# %% [markdown]
# ### Load images
# We load all images into memory.
# So far this works, but we are close to our memory limits.
# We might need to use keras DataGenerators in the future.

# %%
def get_xy_from_df(df, scale: float=1.0):
    X = []
    y = []
    for _, sample in df.iterrows():
        _X = rescale(plt.imread(sample["image"]), scale=scale)
        _y = [sample["break_strain"]]
        X.append(_X)
        y.append(_y)
    X = np.array(X)
    y = np.array(y)
    X = np.expand_dims(X, -1)
    return X, y

# %%
X_train, y_train = get_xy_from_df(df_train, scale=scale)
X_validation, y_validation = get_xy_from_df(df_validation, scale=scale)
X_test, y_test = get_xy_from_df(df_test, scale=scale)

# %% [markdown]
# ### Feature normalization
# We rescale features using train test to learn the rescaling parameters, avoiding data leaking.

# %%
_m = np.mean(X_train, axis=0)
_s = np.std(X_train, axis=0)

X_train = ((X_train - _m) / _s)
X_validation = ((X_validation - _m) / _s)
X_test =  ((X_test - _m) / _s)

# %%
train_data_rescale_params = {
    "mean": _m,
    "std": _s
}
pd.to_pickle(train_data_rescale_params, BASEDIR / "output" / model_name / "dataframes" / "train_data_rescale_params.p")

# %%
pd.to_pickle(X_train, BASEDIR / "output" / model_name / "dataframes" / "X_train.p")
pd.to_pickle(X_validation, BASEDIR / "output" / model_name / "dataframes" / "X_validation.p")
pd.to_pickle(X_test, BASEDIR / "output" / model_name / "dataframes" / "X_test.p")

pd.to_pickle(y_train, BASEDIR / "output" / model_name / "dataframes" / "y_train.p")
pd.to_pickle(y_validation, BASEDIR / "output" / model_name / "dataframes" / "y_validation.p")
pd.to_pickle(y_test, BASEDIR / "output" / model_name / "dataframes" / "y_test.p")

# %% [markdown]
# ### Crash recover
# Uncomment this cell and run to recover from a crash after training.
# Remember to skip training if you do this!

# %%
if False:
  model_name = ""

  df = pd.read_pickle(BASEDIR / "output" / model_name / "dataframes" / "df.p")
  df_subsampled = pd.read_pickle(BASEDIR / "output" / model_name / "dataframes" / "df_subsampled.p")
  df_train = pd.read_pickle(BASEDIR / "output" / model_name / "dataframes" / "df_train.p")
  df_validation = pd.read_pickle(BASEDIR / "output" / model_name / "dataframes" / "df_validation.p")
  df_test = pd.read_pickle(BASEDIR / "output" / model_name / "dataframes" / "df_test.p")


  X_train = pd.read_pickle(BASEDIR / "output" / model_name / "dataframes" / "X_train.p")
  X_validation = pd.read_pickle(BASEDIR / "output" / model_name / "dataframes" / "X_validation.p")
  X_test = pd.read_pickle(BASEDIR / "output" / model_name / "dataframes" / "X_test.p")

  y_train = pd.read_pickle(BASEDIR / "output" / model_name / "dataframes" / "y_train.p")
  y_validation = pd.read_pickle(BASEDIR / "output" / model_name / "dataframes" / "y_validation.p")
  y_test = pd.read_pickle(BASEDIR / "output" / model_name / "dataframes" / "y_test.p")

  history_df = pd.read_pickle(BASEDIR / "output" / model_name / "dataframes" / "history_df.p")

  # recover important settings
  info = dict(pd.read_csv(BASEDIR / "output" / model_name / "model_info.csv").values)
  dropout = float(info["dropout"])
  try:
    training_data_disorder_variance = float(info["disorder_variance"])
  except:
    training_data_disorder_variance = str(info["disorder_variance"])

# %% [markdown]
# ### Model setup
# We use a simple keras + dropout + dense scheme.

# %%
def get_model(dropout: float = 0.0):
  premaid = tf.keras.applications.ResNet50(
      include_top=False,
      pooling="avg",
      weights=None,
      input_shape=X_train[0].shape,
  )

  model = tf.keras.models.Sequential()
  model.add(premaid)
  model.add(tf.keras.layers.Dropout(dropout))
  model.add(tf.keras.layers.Dense(1))
  model.compile(loss="mean_squared_error", optimizer="adam")
  return model

# %%
model = get_model(dropout=dropout)

# %% [markdown]
# ### Model training
# We train for a few epochs, saving weights of best epoch.

# %%
checkpoint_filepath = BASEDIR / "output" / model_name / "checkpoints"

# %%
callbacks = [
    tf.keras.callbacks.ModelCheckpoint(
        filepath=checkpoint_filepath,
        monitor="val_loss",
        save_weights_only=True,
        save_best_only=True,
        ),
]

# %%
history = model.fit(
    X_train, y_train,
    validation_data = (X_validation, y_validation),
    epochs= max_epochs,
    callbacks=callbacks
)
try:
  history_df = pd.concat([history_df, pd.DataFrame(history.history)])
  history_df.index = range(len(history_df))
except:
  history_df = pd.DataFrame(history.history)

# save history df
history_df.to_pickle(BASEDIR / "output" / model_name / "dataframes" / "history_df.p")
# Out:
# Epoch 1/200
# 874/874 [==============================] - 83s 77ms/step - loss: 0.3486 - val_loss: 0.0449
# Epoch 2/200
# 874/874 [==============================] - 65s 75ms/step - loss: 0.0108 - val_loss: 0.0703
# Epoch 3/200
# 874/874 [==============================] - 65s 74ms/step - loss: 0.0119 - val_loss: 0.0470
# Epoch 4/200
# 874/874 [==============================] - 67s 77ms/step - loss: 0.0118 - val_loss: 0.0260
# Epoch 5/200
# 874/874 [==============================] - 66s 76ms/step - loss: 0.0106 - val_loss: 0.0204
# Epoch 6/200
# 874/874 [==============================] - 66s 76ms/step - loss: 0.0096 - val_loss: 0.0018
# Epoch 7/200
# 874/874 [==============================] - 65s 74ms/step - loss: 0.0075 - val_loss: 0.0246
# Epoch 8/200
# 874/874 [==============================] - 65s 74ms/step - loss: 0.0080 - val_loss: 0.0133
# Epoch 9/200
# 874/874 [==============================] - 65s 74ms/step - loss: 0.0075 - val_loss: 0.0111
# Epoch 10/200
# 874/874 [==============================] - 65s 74ms/step - loss: 0.0064 - val_loss: 0.0397
# Epoch 11/200
# 874/874 [==============================] - 65s 74ms/step - loss: 0.0053 - val_loss: 0.0042
# Epoch 12/200
# 874/874 [==============================] - 67s 76ms/step - loss: 0.0059 - val_loss: 6.8592e-04
# Epoch 13/200
# 874/874 [==============================] - 65s 74ms/step - loss: 0.0755 - val_loss: 9.7327e-04
# Epoch 14/200
# 874/874 [==============================] - 65s 74ms/step - loss: 0.0014 - val_loss: 0.0021
# Epoch 15/200
# 874/874 [==============================] - 65s 74ms/step - loss: 0.0019 - val_loss: 0.0042
# Epoch 16/200
# 874/874 [==============================] - 65s 74ms/step - loss: 0.0039 - val_loss: 0.0122
# Epoch 17/200
# 874/874 [==============================] - 65s 74ms/step - loss: 0.0044 - val_loss: 9.9345e-04
# Epoch 18/200
# 874/874 [==============================] - 65s 74ms/step - loss: 0.0042 - val_loss: 0.0047
# Epoch 19/200
# 874/874 [==============================] - 65s 74ms/step - loss: 0.0065 - val_loss: 0.0154
# Epoch 20/200
# 874/874 [==============================] - 66s 75ms/step - loss: 0.0029 - val_loss: 6.7690e-04
# Epoch 21/200
# 874/874 [==============================] - 65s 74ms/step - loss: 0.0030 - val_loss: 0.0048
# Epoch 22/200
# 874/874 [==============================] - 67s 76ms/step - loss: 0.0033 - val_loss: 6.1148e-04
# Epoch 23/200
# 874/874 [==============================] - 65s 74ms/step - loss: 0.0029 - val_loss: 0.0016
# Epoch 24/200
# 874/874 [==============================] - 65s 74ms/step - loss: 0.0023 - val_loss: 0.0098
# Epoch 25/200
# 874/874 [==============================] - 65s 74ms/step - loss: 0.0019 - val_loss: 0.0110
# Epoch 26/200
# 874/874 [==============================] - 65s 74ms/step - loss: 0.0021 - val_loss: 8.4341e-04
# Epoch 27/200
# 874/874 [==============================] - 65s 74ms/step - loss: 0.0018 - val_loss: 0.0156
# Epoch 28/200
# 874/874 [==============================] - 65s 75ms/step - loss: 0.0020 - val_loss: 0.0074
# Epoch 29/200
# 874/874 [==============================] - 65s 75ms/step - loss: 0.0017 - val_loss: 8.5951e-04
# Epoch 30/200
# 874/874 [==============================] - 65s 74ms/step - loss: 0.0018 - val_loss: 0.0013
# Epoch 31/200
# 874/874 [==============================] - 65s 75ms/step - loss: 0.0016 - val_loss: 0.0010
# Epoch 32/200
# 874/874 [==============================] - 65s 75ms/step - loss: 0.0013 - val_loss: 0.0041
# Epoch 33/200
# 874/874 [==============================] - 65s 74ms/step - loss: 0.0012 - val_loss: 0.0067
# Epoch 34/200
# 874/874 [==============================] - 65s 74ms/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 35/200
# 874/874 [==============================] - 65s 75ms/step - loss: 0.0010 - val_loss: 0.0097
# Epoch 36/200
# 874/874 [==============================] - 65s 75ms/step - loss: 0.0011 - val_loss: 0.0025
# Epoch 37/200
# 874/874 [==============================] - 66s 75ms/step - loss: 9.5959e-04 - val_loss: 0.0015
# Epoch 38/200
# 874/874 [==============================] - 66s 75ms/step - loss: 0.0010 - val_loss: 6.8780e-04
# Epoch 39/200
# 874/874 [==============================] - 65s 74ms/step - loss: 0.0012 - val_loss: 0.0044
# Epoch 40/200
# 874/874 [==============================] - 65s 74ms/step - loss: 0.0054 - val_loss: 0.2387
# Epoch 41/200
# 874/874 [==============================] - 65s 75ms/step - loss: 0.0011 - val_loss: 7.8128e-04
# Epoch 42/200
# 874/874 [==============================] - 66s 75ms/step - loss: 0.0010 - val_loss: 6.0525e-04
# Epoch 43/200
# 874/874 [==============================] - 66s 75ms/step - loss: 0.0012 - val_loss: 5.4530e-04
# Epoch 44/200
# 874/874 [==============================] - 66s 75ms/step - loss: 0.0011 - val_loss: 4.2752e-04
# Epoch 45/200
# 874/874 [==============================] - 65s 75ms/step - loss: 9.6810e-04 - val_loss: 4.6392e-04
# Epoch 46/200
# 874/874 [==============================] - 67s 77ms/step - loss: 6.9893e-04 - val_loss: 4.2157e-04
# Epoch 47/200
# 874/874 [==============================] - 66s 76ms/step - loss: 5.8069e-04 - val_loss: 0.0010
# Epoch 48/200
# 874/874 [==============================] - 66s 75ms/step - loss: 6.1833e-04 - val_loss: 4.7192e-04
# Epoch 49/200
# 874/874 [==============================] - 65s 75ms/step - loss: 4.7321e-04 - val_loss: 6.1600e-04
# Epoch 50/200
# 874/874 [==============================] - 65s 75ms/step - loss: 5.9056e-04 - val_loss: 0.0015
# Epoch 51/200
# 874/874 [==============================] - 66s 75ms/step - loss: 0.0013 - val_loss: 7.4310e-04
# Epoch 52/200
# 874/874 [==============================] - 65s 75ms/step - loss: 8.4697e-04 - val_loss: 0.0023
# Epoch 53/200
# 874/874 [==============================] - 65s 75ms/step - loss: 8.2800e-04 - val_loss: 0.0067
# Epoch 54/200
# 874/874 [==============================] - 67s 76ms/step - loss: 6.8054e-04 - val_loss: 3.9683e-04
# Epoch 55/200
# 874/874 [==============================] - 66s 75ms/step - loss: 5.5670e-04 - val_loss: 0.0031
# Epoch 56/200
# 874/874 [==============================] - 66s 75ms/step - loss: 9.2324e-04 - val_loss: 6.3638e-04
# Epoch 57/200
# 874/874 [==============================] - 66s 76ms/step - loss: 7.9768e-04 - val_loss: 0.0015
# Epoch 58/200
# 874/874 [==============================] - 66s 76ms/step - loss: 5.4552e-04 - val_loss: 0.0011
# Epoch 59/200
# 874/874 [==============================] - 66s 76ms/step - loss: 4.9081e-04 - val_loss: 6.9406e-04
# Epoch 60/200
# 874/874 [==============================] - 66s 76ms/step - loss: 4.3778e-04 - val_loss: 4.6506e-04
# Epoch 61/200
# 874/874 [==============================] - 66s 75ms/step - loss: 3.6933e-04 - val_loss: 4.3693e-04
# Epoch 62/200
# 874/874 [==============================] - 65s 74ms/step - loss: 3.5971e-04 - val_loss: 4.5602e-04
# Epoch 63/200
# 874/874 [==============================] - 65s 74ms/step - loss: 3.4995e-04 - val_loss: 7.6944e-04
# Epoch 64/200
# 874/874 [==============================] - 65s 75ms/step - loss: 3.1685e-04 - val_loss: 4.3895e-04
# Epoch 65/200
# 874/874 [==============================] - 66s 75ms/step - loss: 2.8918e-04 - val_loss: 0.0014
# Epoch 66/200
# 874/874 [==============================] - 65s 75ms/step - loss: 3.1381e-04 - val_loss: 4.7035e-04
# Epoch 67/200
# 874/874 [==============================] - 65s 75ms/step - loss: 2.3218e-04 - val_loss: 0.0011
# Epoch 68/200
# 874/874 [==============================] - 68s 77ms/step - loss: 2.2014e-04 - val_loss: 3.2546e-04
# Epoch 69/200
# 874/874 [==============================] - 66s 76ms/step - loss: 1.7554e-04 - val_loss: 3.2472e-04
# Epoch 70/200
# 874/874 [==============================] - 66s 76ms/step - loss: 1.6323e-04 - val_loss: 8.6280e-04
# Epoch 71/200
# 874/874 [==============================] - 66s 76ms/step - loss: 1.6336e-04 - val_loss: 4.6599e-04
# Epoch 72/200
# 874/874 [==============================] - 68s 77ms/step - loss: 1.2501e-04 - val_loss: 3.0801e-04
# Epoch 73/200
# 874/874 [==============================] - 66s 76ms/step - loss: 1.0811e-04 - val_loss: 7.0056e-04
# Epoch 74/200
# 874/874 [==============================] - 65s 75ms/step - loss: 1.0506e-04 - val_loss: 5.3703e-04
# Epoch 75/200
# 874/874 [==============================] - 66s 76ms/step - loss: 9.3996e-05 - val_loss: 3.4641e-04
# Epoch 76/200
# 874/874 [==============================] - 66s 76ms/step - loss: 8.0227e-05 - val_loss: 3.2889e-04
# Epoch 77/200
# 874/874 [==============================] - 66s 75ms/step - loss: 7.2976e-05 - val_loss: 4.9584e-04
# Epoch 78/200
# 874/874 [==============================] - 66s 76ms/step - loss: 7.0830e-05 - val_loss: 2.9851e-04
# Epoch 79/200
# 874/874 [==============================] - 65s 75ms/step - loss: 5.9314e-05 - val_loss: 4.8023e-04
# Epoch 80/200
# 874/874 [==============================] - 65s 75ms/step - loss: 5.8142e-05 - val_loss: 4.7997e-04
# Epoch 81/200
# 874/874 [==============================] - 65s 75ms/step - loss: 5.4854e-05 - val_loss: 3.5061e-04
# Epoch 82/200
# 874/874 [==============================] - 66s 76ms/step - loss: 5.0315e-05 - val_loss: 2.9676e-04
# Epoch 83/200
# 874/874 [==============================] - 65s 75ms/step - loss: 4.6865e-05 - val_loss: 4.2956e-04
# Epoch 84/200
# 874/874 [==============================] - 65s 74ms/step - loss: 4.6794e-05 - val_loss: 3.5967e-04
# Epoch 85/200
# 874/874 [==============================] - 65s 74ms/step - loss: 4.4383e-05 - val_loss: 3.3645e-04
# Epoch 86/200
# 874/874 [==============================] - 65s 74ms/step - loss: 2.8185e-04 - val_loss: 5.1364e-04
# Epoch 87/200
# 874/874 [==============================] - 65s 74ms/step - loss: 2.0234e-04 - val_loss: 3.4643e-04
# Epoch 88/200
# 874/874 [==============================] - 65s 74ms/step - loss: 1.2449e-04 - val_loss: 4.1676e-04
# Epoch 89/200
# 874/874 [==============================] - 65s 75ms/step - loss: 8.6347e-05 - val_loss: 5.4870e-04
# Epoch 90/200
# 874/874 [==============================] - 65s 74ms/step - loss: 6.9038e-05 - val_loss: 4.2284e-04
# Epoch 91/200
# 874/874 [==============================] - 65s 74ms/step - loss: 5.9155e-05 - val_loss: 3.1392e-04
# Epoch 92/200
# 874/874 [==============================] - 65s 74ms/step - loss: 4.8540e-05 - val_loss: 3.7726e-04
# Epoch 93/200
# 874/874 [==============================] - 65s 74ms/step - loss: 4.6373e-05 - val_loss: 3.2138e-04
# Epoch 94/200
# 874/874 [==============================] - 65s 75ms/step - loss: 4.1942e-05 - val_loss: 3.1610e-04
# Epoch 95/200
# 874/874 [==============================] - 65s 74ms/step - loss: 1.2757e-04 - val_loss: 3.1887e-04
# Epoch 96/200
# 874/874 [==============================] - 65s 75ms/step - loss: 6.0296e-05 - val_loss: 3.8789e-04
# Epoch 97/200
# 874/874 [==============================] - 65s 75ms/step - loss: 4.3741e-05 - val_loss: 3.2195e-04
# Epoch 98/200
# 874/874 [==============================] - 65s 74ms/step - loss: 3.8639e-05 - val_loss: 3.5242e-04
# Epoch 99/200
# 874/874 [==============================] - 66s 76ms/step - loss: 4.0058e-05 - val_loss: 2.9234e-04
# Epoch 100/200
# 874/874 [==============================] - 65s 75ms/step - loss: 3.7590e-05 - val_loss: 3.4744e-04
# Epoch 101/200
# 874/874 [==============================] - 65s 75ms/step - loss: 3.5429e-05 - val_loss: 5.7383e-04
# Epoch 102/200
# 874/874 [==============================] - 65s 75ms/step - loss: 3.3174e-05 - val_loss: 5.0593e-04
# Epoch 103/200
# 874/874 [==============================] - 65s 74ms/step - loss: 3.3203e-05 - val_loss: 4.6764e-04
# Epoch 104/200
# 874/874 [==============================] - 65s 74ms/step - loss: 3.4981e-05 - val_loss: 3.6225e-04
# Epoch 105/200
# 874/874 [==============================] - 65s 74ms/step - loss: 3.4236e-05 - val_loss: 5.0408e-04
# Epoch 106/200
# 874/874 [==============================] - 65s 74ms/step - loss: 3.1777e-05 - val_loss: 3.4560e-04
# Epoch 107/200
# 874/874 [==============================] - 65s 75ms/step - loss: 2.9857e-05 - val_loss: 3.0978e-04
# Epoch 108/200
# 874/874 [==============================] - 65s 75ms/step - loss: 2.9077e-05 - val_loss: 3.2844e-04
# Epoch 109/200
# 874/874 [==============================] - 67s 77ms/step - loss: 2.8704e-05 - val_loss: 2.8028e-04
# Epoch 110/200
# 874/874 [==============================] - 65s 75ms/step - loss: 2.6482e-05 - val_loss: 2.9976e-04
# Epoch 111/200
# 874/874 [==============================] - 65s 75ms/step - loss: 2.5470e-05 - val_loss: 3.0776e-04
# Epoch 112/200
# 874/874 [==============================] - 65s 75ms/step - loss: 2.5950e-05 - val_loss: 3.2354e-04
# Epoch 113/200
# 874/874 [==============================] - 65s 75ms/step - loss: 2.4838e-05 - val_loss: 3.2423e-04
# Epoch 114/200
# 874/874 [==============================] - 66s 75ms/step - loss: 2.6590e-05 - val_loss: 3.3395e-04
# Epoch 115/200
# 874/874 [==============================] - 65s 75ms/step - loss: 2.4287e-05 - val_loss: 3.0302e-04
# Epoch 116/200
# 874/874 [==============================] - 65s 75ms/step - loss: 2.6913e-05 - val_loss: 2.8660e-04
# Epoch 117/200
# 874/874 [==============================] - 65s 74ms/step - loss: 2.2262e-05 - val_loss: 3.4554e-04
# Epoch 118/200
# 874/874 [==============================] - 65s 75ms/step - loss: 2.1648e-05 - val_loss: 3.0710e-04
# Epoch 119/200
# 874/874 [==============================] - 65s 75ms/step - loss: 2.1115e-05 - val_loss: 3.0252e-04
# Epoch 120/200
# 874/874 [==============================] - 65s 75ms/step - loss: 2.1687e-05 - val_loss: 2.8792e-04
# Epoch 121/200
# 874/874 [==============================] - 65s 75ms/step - loss: 1.9661e-05 - val_loss: 3.1626e-04
# Epoch 122/200
# 874/874 [==============================] - 65s 75ms/step - loss: 1.9290e-05 - val_loss: 3.1795e-04
# Epoch 123/200
# 874/874 [==============================] - 65s 75ms/step - loss: 2.7236e-05 - val_loss: 3.9675e-04
# Epoch 124/200
# 874/874 [==============================] - 66s 76ms/step - loss: 2.2872e-05 - val_loss: 2.7111e-04
# Epoch 125/200
# 874/874 [==============================] - 65s 75ms/step - loss: 1.8381e-05 - val_loss: 3.0933e-04
# Epoch 126/200
# 874/874 [==============================] - 65s 75ms/step - loss: 1.7882e-05 - val_loss: 2.8580e-04
# Epoch 127/200
# 874/874 [==============================] - 65s 75ms/step - loss: 1.8260e-05 - val_loss: 2.7949e-04
# Epoch 128/200
# 874/874 [==============================] - 65s 75ms/step - loss: 1.6572e-05 - val_loss: 2.9056e-04
# Epoch 129/200
# 874/874 [==============================] - 66s 76ms/step - loss: 1.6851e-05 - val_loss: 2.9751e-04
# Epoch 130/200
# 874/874 [==============================] - 66s 76ms/step - loss: 1.7384e-05 - val_loss: 2.9633e-04
# Epoch 131/200
# 874/874 [==============================] - 66s 76ms/step - loss: 1.6037e-05 - val_loss: 2.9435e-04
# Epoch 132/200
# 874/874 [==============================] - 66s 76ms/step - loss: 1.6558e-05 - val_loss: 3.0846e-04
# Epoch 133/200
# 874/874 [==============================] - 66s 76ms/step - loss: 1.4780e-05 - val_loss: 2.9871e-04
# Epoch 134/200
# 874/874 [==============================] - 66s 76ms/step - loss: 1.4912e-05 - val_loss: 3.0826e-04
# Epoch 135/200
# 874/874 [==============================] - 66s 76ms/step - loss: 1.5365e-05 - val_loss: 2.8060e-04
# Epoch 136/200
# 874/874 [==============================] - 66s 75ms/step - loss: 1.4505e-05 - val_loss: 3.0579e-04
# Epoch 137/200
# 874/874 [==============================] - 65s 75ms/step - loss: 1.3912e-05 - val_loss: 2.8365e-04
# Epoch 138/200
# 874/874 [==============================] - 65s 75ms/step - loss: 1.5364e-05 - val_loss: 2.7907e-04
# Epoch 139/200
# 874/874 [==============================] - 65s 75ms/step - loss: 1.3769e-05 - val_loss: 3.0100e-04
# Epoch 140/200
# 874/874 [==============================] - 65s 75ms/step - loss: 1.3057e-05 - val_loss: 2.7325e-04
# Epoch 141/200
# 874/874 [==============================] - 66s 75ms/step - loss: 1.5355e-05 - val_loss: 3.0669e-04
# Epoch 142/200
# 874/874 [==============================] - 66s 75ms/step - loss: 1.3406e-05 - val_loss: 3.2703e-04
# Epoch 143/200
# 874/874 [==============================] - 66s 75ms/step - loss: 1.3514e-05 - val_loss: 3.0110e-04
# Epoch 144/200
# 874/874 [==============================] - 66s 75ms/step - loss: 1.2433e-05 - val_loss: 4.7645e-04
# Epoch 145/200
# 874/874 [==============================] - 66s 76ms/step - loss: 1.3543e-05 - val_loss: 3.1660e-04
# Epoch 146/200
# 874/874 [==============================] - 66s 75ms/step - loss: 1.2539e-05 - val_loss: 2.8706e-04
# Epoch 147/200
# 874/874 [==============================] - 65s 75ms/step - loss: 1.1509e-05 - val_loss: 2.8726e-04
# Epoch 148/200
# 874/874 [==============================] - 66s 76ms/step - loss: 1.0775e-05 - val_loss: 3.0248e-04
# Epoch 149/200
# 874/874 [==============================] - 66s 75ms/step - loss: 1.2077e-05 - val_loss: 2.8726e-04
# Epoch 150/200
# 874/874 [==============================] - 66s 76ms/step - loss: 1.0995e-05 - val_loss: 2.9247e-04
# Epoch 151/200
# 874/874 [==============================] - 66s 76ms/step - loss: 1.0836e-05 - val_loss: 2.9834e-04
# Epoch 152/200
# 874/874 [==============================] - 65s 75ms/step - loss: 1.0502e-05 - val_loss: 3.0530e-04
# Epoch 153/200
# 874/874 [==============================] - 65s 75ms/step - loss: 1.1455e-05 - val_loss: 3.0925e-04
# Epoch 154/200
# 874/874 [==============================] - 66s 76ms/step - loss: 1.0903e-05 - val_loss: 3.6559e-04
# Epoch 155/200
# 874/874 [==============================] - 66s 75ms/step - loss: 1.0216e-05 - val_loss: 3.0555e-04
# Epoch 156/200
# 874/874 [==============================] - 65s 75ms/step - loss: 1.0561e-05 - val_loss: 2.8498e-04
# Epoch 157/200
# 874/874 [==============================] - 66s 76ms/step - loss: 1.0537e-05 - val_loss: 2.9814e-04
# Epoch 158/200
# 874/874 [==============================] - 67s 76ms/step - loss: 1.0350e-05 - val_loss: 3.0286e-04
# Epoch 159/200
# 874/874 [==============================] - 66s 76ms/step - loss: 1.0715e-05 - val_loss: 3.0076e-04
# Epoch 160/200
# 874/874 [==============================] - 67s 76ms/step - loss: 1.0042e-05 - val_loss: 2.8801e-04
# Epoch 161/200
# 874/874 [==============================] - 66s 76ms/step - loss: 9.0723e-06 - val_loss: 3.2223e-04
# Epoch 162/200
# 874/874 [==============================] - 66s 76ms/step - loss: 9.3352e-06 - val_loss: 2.9375e-04
# Epoch 163/200
# 874/874 [==============================] - 66s 76ms/step - loss: 9.2941e-06 - val_loss: 2.9500e-04
# Epoch 164/200
# 874/874 [==============================] - 67s 76ms/step - loss: 9.7589e-06 - val_loss: 2.9810e-04
# Epoch 165/200
# 874/874 [==============================] - 66s 76ms/step - loss: 8.9615e-06 - val_loss: 2.9481e-04
# Epoch 166/200
# 874/874 [==============================] - 66s 76ms/step - loss: 8.3028e-06 - val_loss: 3.0223e-04
# Epoch 167/200
# 874/874 [==============================] - 66s 76ms/step - loss: 8.6024e-06 - val_loss: 3.2347e-04
# Epoch 168/200
# 874/874 [==============================] - 66s 76ms/step - loss: 8.9646e-06 - val_loss: 2.9738e-04
# Epoch 169/200
# 874/874 [==============================] - 66s 76ms/step - loss: 8.7344e-06 - val_loss: 2.9985e-04
# Epoch 170/200
# 874/874 [==============================] - 66s 76ms/step - loss: 9.3313e-06 - val_loss: 3.0853e-04
# Epoch 171/200
# 874/874 [==============================] - 66s 76ms/step - loss: 7.8919e-06 - val_loss: 2.9925e-04
# Epoch 172/200
# 874/874 [==============================] - 66s 76ms/step - loss: 8.0805e-06 - val_loss: 3.0638e-04
# Epoch 173/200
# 874/874 [==============================] - 66s 76ms/step - loss: 9.4416e-06 - val_loss: 2.8748e-04
# Epoch 174/200
# 874/874 [==============================] - 66s 76ms/step - loss: 7.3849e-06 - val_loss: 3.1726e-04
# Epoch 175/200
# 874/874 [==============================] - 66s 76ms/step - loss: 8.3037e-06 - val_loss: 2.9489e-04
# Epoch 176/200
# 874/874 [==============================] - 66s 76ms/step - loss: 8.0059e-06 - val_loss: 3.1706e-04
# Epoch 177/200
# 874/874 [==============================] - 66s 76ms/step - loss: 8.0374e-06 - val_loss: 2.9725e-04
# Epoch 178/200
# 874/874 [==============================] - 66s 76ms/step - loss: 7.7452e-06 - val_loss: 2.8533e-04
# Epoch 179/200
# 874/874 [==============================] - 66s 76ms/step - loss: 7.5386e-06 - val_loss: 3.1454e-04
# Epoch 180/200
# 874/874 [==============================] - 66s 76ms/step - loss: 6.9797e-06 - val_loss: 2.9568e-04
# Epoch 181/200
# 874/874 [==============================] - 67s 76ms/step - loss: 6.8230e-06 - val_loss: 2.9416e-04
# Epoch 182/200
# 874/874 [==============================] - 66s 76ms/step - loss: 7.1328e-06 - val_loss: 2.9146e-04
# Epoch 183/200
# 874/874 [==============================] - 66s 76ms/step - loss: 6.9983e-06 - val_loss: 3.0025e-04
# Epoch 184/200
# 874/874 [==============================] - 66s 76ms/step - loss: 7.6369e-06 - val_loss: 2.9649e-04
# Epoch 185/200
# 874/874 [==============================] - 66s 76ms/step - loss: 6.7451e-06 - val_loss: 3.0514e-04
# Epoch 186/200
# 874/874 [==============================] - 66s 76ms/step - loss: 6.8031e-06 - val_loss: 2.9599e-04
# Epoch 187/200
# 874/874 [==============================] - 66s 76ms/step - loss: 6.8034e-06 - val_loss: 3.0608e-04
# Epoch 188/200
# 874/874 [==============================] - 66s 76ms/step - loss: 7.7690e-06 - val_loss: 3.3521e-04
# Epoch 189/200
# 874/874 [==============================] - 66s 76ms/step - loss: 6.8496e-06 - val_loss: 3.0365e-04
# Epoch 190/200
# 874/874 [==============================] - 66s 76ms/step - loss: 6.6708e-06 - val_loss: 2.9648e-04
# Epoch 191/200
# 874/874 [==============================] - 66s 76ms/step - loss: 6.4318e-06 - val_loss: 3.0843e-04
# Epoch 192/200
# 874/874 [==============================] - 66s 76ms/step - loss: 6.2811e-06 - val_loss: 3.0343e-04
# Epoch 193/200
# 874/874 [==============================] - 66s 76ms/step - loss: 6.1044e-06 - val_loss: 2.9398e-04
# Epoch 194/200
# 874/874 [==============================] - 66s 76ms/step - loss: 6.8312e-06 - val_loss: 2.9842e-04
# Epoch 195/200
# 874/874 [==============================] - 66s 76ms/step - loss: 6.2088e-06 - val_loss: 3.0402e-04
# Epoch 196/200
# 874/874 [==============================] - 66s 76ms/step - loss: 5.7411e-06 - val_loss: 2.9728e-04
# Epoch 197/200
# 874/874 [==============================] - 66s 76ms/step - loss: 6.8349e-06 - val_loss: 3.0276e-04
# Epoch 198/200
# 874/874 [==============================] - 66s 76ms/step - loss: 6.2412e-06 - val_loss: 2.9904e-04
# Epoch 199/200
# 874/874 [==============================] - 66s 76ms/step - loss: 6.4151e-06 - val_loss: 3.0893e-04
# Epoch 200/200
# 874/874 [==============================] - 66s 76ms/step - loss: 5.7533e-06 - val_loss: 3.0276e-04

# %% [markdown]
# ### Model predictions
# We load the best weights and do predictions

# %%
model.load_weights(checkpoint_filepath)

# %%
y_test_pred = model.predict(X_test)
y_train_pred = model.predict(X_train)

# %%
raw_results_df_test = df_test.copy()
raw_results_df_test["target"] = y_test.T[0]
raw_results_df_test["prediction"] = y_test_pred.T[0]
results_df_test = raw_results_df_test.groupby("run").median().reset_index()

# %%
raw_results_df_train = df_train.copy()
raw_results_df_train["target"] = y_train.T[0]
raw_results_df_train["prediction"] = y_train_pred.T[0]
results_df_train = raw_results_df_train.groupby("run").median().reset_index()

# %% [markdown]
# ### Save model predictions

# %%
raw_results_df_train.to_pickle(BASEDIR / "output" / model_name / "dataframes" / "raw_results_df_train.p")
raw_results_df_test.to_pickle(BASEDIR / "output" / model_name / "dataframes" / "raw_results_df_test.p")
results_df_train.to_pickle(BASEDIR / "output" / model_name / "dataframes" / "results_df_train.p")
results_df_test.to_pickle(BASEDIR / "output" / model_name / "dataframes" / "results_df_test.p")

# %% [markdown]
# ### Plot results

# %%
def plot_resampling():
  fig, ax = plt.subplots(1, 1, figsize=(5, 4))
  a, b = 0.03, 0.22
  bins = np.linspace(a, b)
  ax.hist(df.break_strain, bins=bins, density=False, color="0.2", histtype="step", ls="dashed", label="Original")
  ax.hist(df.break_strain, bins=bins, density=False, color="0.2", alpha=0.1)
  ax.hist(df_subsampled.break_strain, bins=bins, density=False, color="blue", alpha=1, histtype="step", lw=2, label="Resampled")
  ax.hist(df_subsampled.break_strain, bins=bins, density=False, color="blue", alpha=0.2)
  ax.set_xlim(a, b)
  ax.set_xlabel("Rupture strain")
  ax.legend()
  return fig, ax

# %%
def plot_results(results_df: pd.DataFrame, label="LABEL"):
  x, y = results_df.target, results_df.prediction
  R2 = linregress(x, y).rvalue ** 2

  fig, ax = plt.subplots(1, 1, figsize=(5, 4))
  

  sns.regplot(x, y, ax=ax, truncate=False, color=colors_dict[label])
  
  ax.set_xlabel("Rupture strain")
  ax.set_ylabel("Model prediction")

  ax.set_aspect(1)
  ax.text(0.1, 0.95, f"$R^2 = {R2:.2f}$\n{label}", fontsize=14, transform=ax.transAxes, va="top", ha="left")
  return fig, ax

# %%
def plot_errors(results_df: pd.DataFrame, label="LABEL"):
  percent_error = (results_df.prediction / results_df.target - 1) * 100
  fig, ax = plt.subplots(1, 1, figsize=(5, 4), tight_layout=True)
  sns.distplot(percent_error, ax=ax, label="Ensemble pred", hist=True, color=colors_dict[label])
  xticks = ax.get_xticks()
  ax.set_xticks(xticks)
  ax.text(0.05, 0.9, label, transform=ax.transAxes, fontsize=14)  
  xticklabels = [f"{int(x)}%" for x in xticks]
  ax.set_xticklabels(xticklabels)
  ax.set_xlabel("Relative error")
  return fig, ax

# %%
def plot_history(history_df: pd.DataFrame):
  fig, ax = plt.subplots(1, 1, figsize=(5, 4))
  ax.plot(history_df.loss, marker="o", ms=7, label="Train set", color=colors_dict["TRAIN SET"])
  ax.plot(history_df.val_loss, marker="o", ms=7, label="Validation set", color=colors_dict["VALIDATION SET"])
  ax.legend(frameon=False)
  ax.set_xlabel("Epoch")
  ax.set_ylabel("Loss function (MSE)")
  ax.set_yscale("log")
  return fig, ax

# %%
colors_dict = {
    "TRAIN SET":"0.5",
    "VALIDATION SET": "#ff2d55",
    "TEST SET": "#007aff",
}

# %%
fig, ax = plot_resampling()
fig.savefig(BASEDIR / "output" / model_name / "figures" / "rupture_strain_resampling.png", dpi=150)

# %%
fig, ax = plot_results(results_df=results_df_train, label="TRAIN SET")
fig.savefig(BASEDIR / "output" / model_name / "figures" / "results_train_set.png", dpi=150)

fig, ax = plot_results(results_df=results_df_test, label="TEST SET")
fig.savefig(BASEDIR / "output" / model_name / "figures" / "results_test_set.png", dpi=150)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
fig, ax = plot_history(history_df=history_df)
fig.savefig(BASEDIR / "output" / model_name / "figures" / "loss_function.png", dpi=150)

# %%
if training_data_disorder_variance == "variable":
  results_df_test["disorder_var_q"] = pd.qcut(results_df_test.disorder_var, 3, labels=["low", "med", "high"])
  colors = {
      "low": "#7bc775",  
      "med": "#f6cd61",
      "high": "#fe8a71"
  }
  fig, ax = plt.subplots(1, 1, figsize=(8, 4), tight_layout=True)
  ax.set_aspect(1)
  a, b = (0.03749375, 0.195125)
  ax.set_xlim(a, b)
  for lab, sdf in results_df_test.groupby("disorder_var_q"):
    _x, _y = sdf.target, sdf.prediction
    R2 = linregress(_x, _y).rvalue ** 2
    sns.regplot(_x, _y, truncate=False, color=colors[lab], label=lab + f" disorder ($R^2={R2:.02}$)" )
  ax.plot([a, b], [a, b], ls="dashed", c="0.2")
  ax.legend(loc=(1, 0), frameon=False)
  ax.set_xlabel("Rupture strain")
  ax.set_ylabel("Model prediction")
  fig.savefig(BASEDIR / "output" / model_name / "figures" / "strain_prediction_variable_disorder.png", dpi=150)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
